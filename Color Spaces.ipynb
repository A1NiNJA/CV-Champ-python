# %% [markdown]
# ## Let's take a closer look at color spaces
#
# You may have remembered we talked about images being stored in RGB (Red Green Blue) color Spaces. Let's take a look at that in OpenCV.
#
# ### First thing to remember about OpenCV's RGB is that it's BGR (I know, this is annoying)
#
# Let's look at the image shape again. The '3L'

# %%
from google.colab import drive
drive.mount('/content/drive')

import cv2
import numpy as np

image = cv2.imread('/content/drive/MyDrive/ColabNotebook1/images/flowers-right.png')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Let's look at the individual color levels for the first pixel (0,0)

# %%
import cv2

# BGR Values for the first 0,0 pixel
B, G, R = image[10, 50] 
print(B, G, R)
print(image.shape)
# Out:
# 236 232 231
# (352, 512, 3)

# %% [markdown]
# Let's see what happens when we convert it to grayscale

# %%
gray_img = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
print(gray_img.shape)
print(gray_img[10, 50])
# Out:
# (352, 512)
# 232

# %% [markdown]
# It's now only 2 dimensions. Each pixel coordinate has only one value (previously 3) with a range of 0 to 255

# %%
gray_img[0, 0]
# Out:
# 228

# %% [markdown]
# ### Another useful color space is HSV
# Infact HSV is very useful in color filtering.

# %%
import cv2

#H: 0 - 180, S: 0 - 255, V: 0 - 255

image = cv2.imread('/content/drive/MyDrive/ColabNotebook1/images/flowers-right.png')

hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

from google.colab.patches import cv2_imshow

cv2_imshow(hsv_image)
cv2_imshow(hsv_image[:, :, 0])
cv2_imshow(hsv_image[:, :, 1])
cv2_imshow(hsv_image[:, :, 2])

cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=512x352 at 0x7FCAE1A0C8D0>
# <PIL.Image.Image image mode=L size=512x352 at 0x7FCAE195CF90>
# <PIL.Image.Image image mode=L size=512x352 at 0x7FCAE1A0C8D0>
# <PIL.Image.Image image mode=L size=512x352 at 0x7FCAE195CE10>

# %% [markdown]
# ### Let's now explore lookng at individual channels in an RGB image

# %%
image = cv2.imread('/content/drive/MyDrive/ColabNotebook1/images/flowers-right.png')

# OpenCV's 'split' function splites the image into each color index
B, G, R = cv2.split(image)

from google.colab.patches import cv2_imshow

print(B.shape)
cv2_imshow(R)
cv2_imshow(G)
cv2_imshow(B)
cv2.waitKey(0)
cv2.destroyAllWindows()

# Let's re-make the original image, 
merged = cv2.merge([B, G, R]) 
cv2_imshow(merged) 

# Let's amplify the blue color
merged = cv2.merge([B+100, G, R])
cv2_imshow(merged) 

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# (352, 512)
# <PIL.Image.Image image mode=L size=512x352 at 0x7FCAE197C790>
# <PIL.Image.Image image mode=L size=512x352 at 0x7FCAE197C4D0>
# <PIL.Image.Image image mode=L size=512x352 at 0x7FCAE1A07410>
# <PIL.Image.Image image mode=RGB size=512x352 at 0x7FCAE197C150>
# <PIL.Image.Image image mode=RGB size=512x352 at 0x7FCAE197C790>

# %%
import cv2
import numpy as np

B, G, R = cv2.split(image)

# Let's create a matrix of zeros 
# with dimensions of the image h x w  
zeros = np.zeros(image.shape[:2], dtype = "uint8")

from google.colab.patches import cv2_imshow

cv2_imshow(cv2.merge([zeros, zeros, R]))
cv2_imshow(cv2.merge([zeros, G, zeros]))
cv2_imshow(cv2.merge([B, zeros, zeros]))

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=512x352 at 0x7FCAE19845D0>
# <PIL.Image.Image image mode=RGB size=512x352 at 0x7FCAE1984750>
# <PIL.Image.Image image mode=RGB size=512x352 at 0x7FCAE19845D0>

# %%
image.shape[:2]
# Out:
# (830L, 1245L)

# %% [markdown]
# #### You can view a list of color converisons here, but keep in mind you won't ever use or need many of these
#
# http://docs.opencv.org/trunk/d7/d1b/group__imgproc__misc.html#ga4e0972be5de079fed4e3a10e24ef5ef0
